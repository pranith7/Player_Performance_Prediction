# %%
pip install --pre pycaret

# %%
from pycaret.regression import *
import pandas as pd 
import numpy as np

# %%
train = pd.read_csv("/home/pranith/Desktop/Development/Player_Performance_Prediction/training_Data.csv")
validation = pd.read_csv("/home/pranith/Desktop/Development/Player_Performance_Prediction/validation_data.csv")

# %%
train.head()
# Out:
#    Unnamed: 0         batting_team         bowling_team  match_id  start_date  \
# 0         769  Chennai Super Kings       Mumbai Indians   1136561  2018-04-07
# 1         768  Chennai Super Kings       Mumbai Indians   1136561  2018-04-07
# 2         767  Chennai Super Kings       Mumbai Indians   1136561  2018-04-07
# 3         765  Chennai Super Kings       Mumbai Indians   1136561  2018-04-07
# 4        7614       Mumbai Indians  Chennai Super Kings   1136561  2018-04-07
#
#            striker  Batsman_runs  Balls  Fours  Sixes  Fifties  Hundreds  \
# 0      Imran Tahir             2      2    0.0    0.0        0         0
# 1  Harbhajan Singh             8      6    1.0    0.0        0         0
# 2        DL Chahar             0      1    0.0    0.0        0         0
# 3        AT Rayudu            22     19    4.0    0.0        0         0
# 4          E Lewis             0      2    0.0    0.0        0         0
#
# ...

# %%
s = setup(train, target = 'dreamll_score')
# Out:
# <style type="text/css">
# #T_21fe9_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_21fe9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21fe9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_21fe9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21fe9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21fe9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_21fe9_row0_col1" class="data row0 col1" >1808</td>
#     </tr>
#     <tr>
#       <th id="T_21fe9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21fe9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_21fe9_row1_col1" class="data row1 col1" >dreamll_score</td>
#     </tr>
#     <tr>
#       <th id="T_21fe9_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_ff457 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LinearRegression(n_jobs=-1)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'feature')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e1d23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1d23_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e1d23_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e1d23_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e1d23_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e1d23_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e1d23_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e1d23_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1d23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1d23_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_e1d23_row0_col1" class="data row0 col1" >0.0000</td>
# ...

# %%
predictions = predict_model(best, data=validation)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa94f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa94f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fa94f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fa94f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fa94f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fa94f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fa94f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fa94f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa94f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa94f_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_fa94f_row0_col1" class="data row0 col1" >0.0000</td>
# ...
